# %% [markdown]
# # Sleep summary
#
# Counts nights per participant. Invented for the test suite.

# %%
import pandas as pd

def nights_per_participant(frame):
    """Counts the nights recorded for each participant."""
    return frame.groupby("participant_id").size()
# Out:
# participant_id  nights
# SECRET-OUTPUT-ROW 12

# %%
summary = nights_per_participant(readings)
